# %% [markdown]
# <a href="https://colab.research.google.com/github/collinskoech11/MachineLearning/blob/master/SampleDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x= [1,2,3]
y = [1,4,9]
z = [10,5,0]
plt.plot(x,y) #plot x on x axis and y on y axis 
plt.plot(x,z)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is y ", " this is z"])
plt.show()
